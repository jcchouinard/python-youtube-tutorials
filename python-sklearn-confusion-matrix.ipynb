# %% [markdown]
# # Confusion Matrix in Python (with Scikit-Learn)
#
# By: jcchouinard.com
#
# -----
#
# ## What is a Confusion Matrix
#
# A confusion matrix measures the quality of predictions from a classification model by looking at how many predictions are True and how many are False.
#
# Specifically, it computes:
#
# - `True positives (TP)`: predicted true and it is true. Predicted that someone `is sick` and the person `is sick`.
# - `False positives (FP)`: predicted false and it is false. Predicted that someone `is not sick` and the person `is not sick`.
# - `True negatives (TN)`: predicted True and it is false. Predicted that someone `is sick` and the person `is not sick`.
# - `False negatives (FN)`: predicted false and it is true. Predicted that someone `is not sick` and the person `is sick`.
#
#
# ##  Example
#
# ![](https://www.jcchouinard.com/wp-content/uploads/2023/09/confusion-matrix.jpg)

# %% [markdown]
# ## Train a Machine Learning Model

# %%
# Import necessary libraries
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd

# Load the dataset
X, y = load_breast_cancer(return_X_y=True)

# split taining and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# train the model
knn = KNeighborsClassifier(n_neighbors=8)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

# compute accuracy of the model
knn.score(X_test, y_test)
# Out:
# 0.9298245614035088

# %% [markdown]
# ## Create a Confusion Matrix in Python

# %%
from sklearn.metrics import confusion_matrix
 
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[ 57,   7],
#        [  5, 102]])

# %%
print('TN:', cm[0][0], 'predicted IS SICK and person IS NOT SICK')
print('FP:', cm[0][1], 'predicted IS NOT SICK and person IS NOT SICK')
print('FN:', cm[1][0], 'predicted IS NOT SICK and person IS SICK')
print('TP:', cm[1][1], 'predicted IS SICK and person IS SICK')
# Out:
# TP: 57 predicted IS SICK and person IS SICK
# FP: 7 predicted IS NOT SICK and person IS NOT SICK
# FN: 5 predicted IS NOT SICK and person IS SICK
# TN: 102 predicted IS SICK and person IS NOT SICK

# %% [markdown]
# ## Plot the Confusion Matrix

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix

labels = knn.classes_
cm = confusion_matrix(y_test, y_pred, labels=labels)
color = 'white'
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot()
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## Confusion Matrix for Multi-Class Classification

# %%
#Import the necessary libraries
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
 
# Load the wine dataset
X, y = load_wine(return_X_y=True)

# Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25)
  
# Train the model
clf = RandomForestClassifier(random_state=23)
clf.fit(X_train, y_train)
  
# Predict using the test data
y_pred = clf.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9777777777777777

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_test,y_pred)
  
# Plot the confusion matrix.
sns.heatmap(cm,
            annot=True)

# Plot Multi-cass confusion matrix 
plt.ylabel('Actual')
plt.xlabel('Prediction')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## Use Confusion Matrix with Classification Report

# %%
# Classification report
from sklearn.metrics import classification_report
 
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97        14
#            1       1.00      0.94      0.97        17
#            2       1.00      1.00      1.00        14
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# ## Conclusion
#
# Help me and subscribe to this channel.
#
# Stay tuned for my upcoming Python for SEO course.
#
# ### [jcchouinard.com](https://www.jcchouinard.com/)
# ### [youtube.com/@jcchouinard](https://www.youtube.com/@jcchouinard)
# ### [twitter.com/ChouinardJC](https://twitter.com/ChouinardJC)
# ### [linkedin.com/in/jeanchristophechouinard](https://www.linkedin.com/in/jeanchristophechouinard)
